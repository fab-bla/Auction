# %% [markdown]
# <a href="https://colab.research.google.com/github/Base-R-Best-R/Auction/blob/main/Code/Models/Colab/XGboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# call R in Python
# %reload_ext rpy2.ipython

# %%
# mount gdrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# R
# %%R

# install and load packages
install.packages(c("xgboost"))
library(xgboost)

# %%
# R
# %%R

# load required data 
dat_aucs_eng <- readRDS("drive/MyDrive/Colab Transfer/Aucs_df_feateng_split.RDS")

# rm vars
lapply(dat_aucs_eng, \(x){

  # remove
  x$Contract_ID <- NULL
  x$MLOT <- NULL
  x$EW_Diff <- NULL
  Label <- x$Winning_Bid / 1e3
  x$Winning_Bid <- NULL
  x$Eng_Est <- x$Eng_Est /1e3
  
  # feature model matrix
  mod_mat <-  model.matrix(~. + 0, data = x)
  
  # Label and hot encoded features
  list("Label" = Label,
       "Features" = mod_mat,
       "XGB_Matrix" = xgb.DMatrix(data = mod_mat, label = Label))
  
}) -> dat_aucs_mod

# tuning grid
XGgrid <- expand.grid("objective" = "reg:squarederror",
                      "booster" = "gbtree",
                      "eta" = seq(0.05, 0.25, 0.1), 
                      "gamma" = seq(0.1, 9, 3),
                      "max_depth" = seq(5, 100, 25),
                      "min_child_weight" = seq(3, 9, 3),
                      "subsample" = seq(0.6, 1, 0.3),
                      "colsample_bytree" = seq(0.6, 1, 0.3),
                      "lambda" = seq(0.1, 9, 3),
                      "alpha" = seq(0.1, 9, 3))

# %%
# R
# %%R

# parameter optimization CV
xgb.cv_opt <- \(nrounds = 1e3, print_every_n = 2e3, nfold = 5, 
                early_stopping_rounds = 10, maximize = FALSE, metrics = c("mae", "rmse"), 
                verbosity = 0, seed = 33, data, tuning_grid){
  
  # nmodels
  nmod <- nrow(tuning_grid)
  
  # metric subset vector
  sub_pst <- paste0("test_", metrics, "_mean")
  
  # print 
  cat(paste0(Sys.time(), ", starting CV: ", nmod, " models to fit!\n\n"))
  
  # counter
  count <- 1
  
  # over tuning grid rows
  apply(tuning_grid, 1, \(row){
    
    # parameters to list 
    param_lst <- as.list(row)
    
    # seed (s.t. we may compare the different models across the same folds)
    set.seed(seed)
    
    # cv 
    cv_tmp <- xgb.cv(params = param_lst, nrounds = nrounds, 
                     nfold = nfold, print_every_n = print_every_n,
                     early_stopping_rounds = early_stopping_rounds,
                     maximize = maximize, metrics = metrics, verbosity = verbosity,
                     data = data)
    
    # print current State
    cat(paste0(count, "/", nmod, " fit!\n"))
    
    # count
    count <<- count + 1

    # extract best iteration + input parameters
    cbind(cv_tmp[["evaluation_log"]][cv_tmp[["best_iteration"]], c("iter", sub_pst), with = FALSE] |> 
          data.matrix(),
          t(data.matrix(row)))
    
  }) -> tmp
  
  # rownames
  rownames(tmp) <- c("iter", sub_pst, colnames(tuning_grid))
  
  # return
  return(tmp)
}

# %%
# R
# %%R

# run 
# res <- xgb.cv_opt(data = dat_aucs_mod[["Train"]][["XGB_Matrix"]], tuning_grid = XGgrid)

# save 
# saveRDS(res, "drive/MyDrive/Master_Thesis/Models_MT/XGBoost_feateng.RDS")

# %%
# R
# %%R

# updated tuning grid
XGgrid_r2 <- expand.grid("objective" = "reg:squarederror",
                      "booster" = "gbtree",
                      "eta" = seq(0.01, 0.05, 0.02), 
                      "gamma" = c(0.05, 0.1, 0.5, 1),
                      "max_depth" = c(3, 5, 10),
                      "min_child_weight" = seq(1, 5, 2),
                      "subsample" = seq(0.9, 1, 0.1),
                      "colsample_bytree" = seq(0.9, 1, 0.1),
                      "lambda" = seq(5, 10, 2),
                      "alpha" = seq(2, 4, 2))

# rerun CV
# res <- xgb.cv_opt(data = dat_aucs_mod[["Train"]][["XGB_Matrix"]], tuning_grid = XGgrid_r2)

# save 
# saveRDS(res, "drive/MyDrive/Master_Thesis/Models_MT/CV_XGBoost_feateng_r2.RDS")

# %%
# R
# %%R

# 3rd run tuning grid
XGgrid_r3 <- expand.grid("objective" = "reg:squarederror",
                         "booster" = "gbtree",
                         "eta" = seq(0.04, 0.06, 0.01), 
                         "gamma" = c(0.03, 0.05, 0.1),
                         "max_depth" = c(4, 5, 6),
                         "min_child_weight" = 1,
                         "subsample" = seq(0.85, 0.95, 0.05),
                         "colsample_bytree" = seq(0.85, 0.95, 0.05),
                         "lambda" = seq(6, 8, 1),
                         "alpha" = seq(3, 7, 2))

# rerun CV
# res <- xgb.cv_opt(data = dat_aucs_mod[["Train"]][["XGB_Matrix"]], tuning_grid = XGgrid_r3)

# save 
# saveRDS(res, "drive/MyDrive/Master_Thesis/Models_MT/CV_XGBoost_feateng_r3.RDS")

# %%
# R
# %%R

# 4th run
XGgrid_r4 <- expand.grid("objective" = "reg:squarederror",
                         "booster" = "gbtree",
                         "eta" = seq(0.02, 0.04, 0.01), 
                         "gamma" = c(0.03, 0.04, 0.01),
                         "max_depth" = c(6, 7),
                         "min_child_weight" = 1,
                         "subsample" = 0.9,
                         "colsample_bytree" = 0.9,
                         "lambda" = seq(8, 11, 1),
                         "alpha" = seq(2, 4, 1))

# rerun CV
# res <- xgb.cv_opt(data = dat_aucs_mod[["Train"]][["XGB_Matrix"]], tuning_grid = XGgrid_r4)

# save 
# saveRDS(res, "drive/MyDrive/Master_Thesis/Models_MT/CV_XGBoost_feateng_r4.RDS")

# %%
# R
# %%R

# final run
XGgrid_r5 <- expand.grid("objective" = "reg:squarederror",
                         "booster" = "gbtree",
                         "eta" = 0.04, 
                         "gamma" = c(0.01, 0.02),
                         "max_depth" = seq(7, 10, 1),
                         "min_child_weight" = 1,
                         "subsample" = 0.9,
                         "colsample_bytree" = 0.9,
                         "lambda" = seq(8, 11, 1),
                         "alpha" = seq(3, 4, 1))

# rerun CV
res <- xgb.cv_opt(data = dat_aucs_mod[["Train"]][["XGB_Matrix"]], tuning_grid = XGgrid_r5)

# save 
saveRDS(res, "drive/MyDrive/Master_Thesis/Models_MT/CV_XGBoost_feateng_r5.RDS")
# Out:
# 2022-07-07 11:37:45, starting CV: 64 models to fit!
#
# [1]	train-mae:3441.544337+120.460723	train-rmse:6178.137871+669.856601	test-mae:3441.557388+502.598463	test-rmse:5825.646478+2172.454246
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [338]	train-mae:67.832371+14.271790	train-rmse:476.367481+201.246882	test-mae:573.186898+369.805914	test-rmse:1568.485650+1893.405144
#
# 1/64 fit!
# [1]	train-mae:3441.544337+120.460723	train-rmse:6178.137871+669.856601	test-mae:3441.557388+502.598463	test-rmse:5825.646478+2172.454246
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
#
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [404]	train-mae:42.775046+12.105062	train-rmse:471.231032+206.113510	test-mae:599.235294+376.448936	test-rmse:1604.710948+1900.776675
#
# 23/64 fit!
# [1]	train-mae:3449.374964+120.890381	train-rmse:6184.174556+670.414355	test-mae:3446.344982+500.795152	test-rmse:5829.917029+2171.523380
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [404]	train-mae:42.751338+12.126799	train-rmse:471.219476+206.128999	test-mae:599.295678+376.528987	test-rmse:1604.699375+1900.802886
#
# 24/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:62.221119+13.910312	train-rmse:504.234663+215.409943	test-mae:587.316239+376.957443	test-rmse:1587.342750+1900.688750
#
# 25/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:62.221063+13.910278	train-rmse:504.234662+215.409942	test-mae:587.316205+376.957456	test-rmse:1587.342750+1900.688749
#
# 26/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [428]	train-mae:51.721202+12.961302	train-rmse:485.177702+210.005982	test-mae:595.766130+373.503215	test-rmse:1594.938370+1900.566371
#
# 27/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [428]	train-mae:51.732925+12.967811	train-rmse:485.174937+210.004571	test-mae:595.817882+373.478840	test-rmse:1594.882034+1900.586854
#
# 28/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [416]	train-mae:48.427480+13.054197	train-rmse:503.023796+217.173103	test-mae:597.924653+372.506033	test-rmse:1598.150629+1903.715211
#
# 29/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [415]	train-mae:48.498059+13.040137	train-rmse:504.733620+217.812439	test-mae:597.820136+372.641256	test-rmse:1598.183011+1903.980434
#
# 30/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:44.665628+12.946161	train-rmse:501.995993+218.728642	test-mae:599.405379+370.262977	test-rmse:1600.101565+1900.242357
#
# 31/64 fit!
# [1]	train-mae:3447.420820+122.551652	train-rmse:6188.631701+670.380790	test-mae:3443.427726+504.413370	test-rmse:5832.035384+2178.549083
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:44.649515+12.935358	train-rmse:501.983848+218.723248	test-mae:599.507245+370.218316	test-rmse:1600.146999+1900.220809
#
# 32/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [339]	train-mae:67.957086+14.139173	train-rmse:474.383043+200.191371	test-mae:574.501822+369.758203	test-rmse:1569.842935+1892.922969
#
# 33/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [339]	train-mae:67.957091+14.139176	train-rmse:474.383043+200.191371	test-mae:574.501818+369.758206	test-rmse:1569.842936+1892.922969
#
# 34/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [362]	train-mae:52.362629+12.899581	train-rmse:428.113837+185.344613	test-mae:578.791936+368.977198	test-rmse:1570.324969+1888.025849
#
# 35/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [362]	train-mae:52.362883+12.899688	train-rmse:428.113838+185.344614	test-mae:578.793112+368.976667	test-rmse:1570.325481+1888.025598
#
# 36/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [346]	train-mae:48.883191+13.561074	train-rmse:456.987781+198.126033	test-mae:586.934998+369.255210	test-rmse:1583.434948+1889.274951
#
# 37/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [346]	train-mae:48.889717+13.548086	train-rmse:456.991669+198.118269	test-mae:586.951365+369.287704	test-rmse:1583.438699+1889.282453
#
# 38/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [359]	train-mae:41.901533+12.311709	train-rmse:429.858975+188.630131	test-mae:592.151260+366.054790	test-rmse:1587.381113+1878.118422
#
# 39/64 fit!
# [1]	train-mae:3441.545027+120.460715	train-rmse:6178.138254+669.856543	test-mae:3441.558100+502.598506	test-rmse:5825.646934+2172.454115
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [359]	train-mae:41.901509+12.311666	train-rmse:429.858970+188.630133	test-mae:592.151673+366.054558	test-rmse:1587.381311+1878.118321
#
# 40/64 fit!
# [1]	train-mae:3446.178149+119.265967	train-rmse:6181.079113+669.857250	test-mae:3446.286403+501.306894	test-rmse:5828.844009+2170.711021
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [360]	train-mae:66.829270+13.884889	train-rmse:495.553725+209.965279	test-mae:582.401041+374.987533	test-rmse:1584.138636+1890.242789
#
# 41/64 fit!
# [1]	train-mae:3446.178149+119.265967	train-rmse:6181.079113+669.857250	test-mae:3446.286403+501.306894	test-rmse:5828.844009+2170.711021
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [360]	train-mae:66.829288+13.884898	train-rmse:495.553726+209.965279	test-mae:582.401015+374.987544	test-rmse:1584.138611+1890.242801
#
# 42/64 fit!
# [1]	train-mae:3446.178149+119.265967	train-rmse:6181.079113+669.857250	test-mae:3446.286403+501.306894	test-rmse:5828.844009+2170.711021
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [370]	train-mae:54.350261+13.588032	train-rmse:473.994014+204.345373	test-mae:584.633618+372.097796	test-rmse:1589.522520+1890.301557
#
# 43/64 fit!
# [1]	train-mae:3446.178149+119.265967	train-rmse:6181.079113+669.857250	test-mae:3446.286403+501.306894	test-rmse:5828.844009+2170.711021
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
#
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [404]	train-mae:46.513656+12.540462	train-rmse:472.182933+205.956759	test-mae:592.991483+377.694244	test-rmse:1596.907094+1899.029673
#
# 54/64 fit!
# [1]	train-mae:3449.375671+120.890373	train-rmse:6184.175049+670.414333	test-mae:3446.345651+500.795171	test-rmse:5829.917502+2171.523255
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [404]	train-mae:42.776218+12.223695	train-rmse:471.204394+206.171815	test-mae:598.237814+375.937010	test-rmse:1602.867580+1899.693761
#
# 55/64 fit!
# [1]	train-mae:3449.375671+120.890373	train-rmse:6184.175049+670.414333	test-mae:3446.345651+500.795171	test-rmse:5829.917502+2171.523255
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [404]	train-mae:42.798860+12.235821	train-rmse:471.199212+206.169531	test-mae:598.217957+375.946193	test-rmse:1603.023750+1899.617562
#
# 56/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:62.110276+13.749102	train-rmse:504.182181+215.100849	test-mae:588.039589+377.989937	test-rmse:1590.759663+1905.946210
#
# 57/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:62.110280+13.749106	train-rmse:504.182181+215.100849	test-mae:588.039590+377.989926	test-rmse:1590.759674+1905.946202
#
# 58/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:53.574313+12.986698	train-rmse:503.164630+216.642637	test-mae:595.239694+374.986918	test-rmse:1594.111806+1905.317890
#
# 59/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [417]	train-mae:53.613849+13.110678	train-rmse:502.911433+216.532714	test-mae:594.943245+375.276689	test-rmse:1593.799113+1905.465234
#
# 60/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [415]	train-mae:48.546720+13.072968	train-rmse:505.076775+218.051102	test-mae:597.364473+372.867481	test-rmse:1597.310040+1905.013181
#
# 61/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [416]	train-mae:48.418447+13.056260	train-rmse:503.370182+217.415492	test-mae:597.410773+372.757351	test-rmse:1597.425980+1904.673632
#
# 62/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [428]	train-mae:43.130517+12.578105	train-rmse:484.379418+212.016025	test-mae:600.173418+369.476226	test-rmse:1598.744382+1896.535864
#
# 63/64 fit!
# [1]	train-mae:3447.421429+122.551643	train-rmse:6188.632100+670.380806	test-mae:3443.428329+504.413384	test-rmse:5832.035816+2178.548944
# Multiple eval metrics are present. Will use test_rmse for early stopping.
# Will train until test_rmse hasn't improved in 10 rounds.
#
# Stopping. Best iteration:
# [428]	train-mae:43.140438+12.582917	train-rmse:484.370277+212.011480	test-mae:600.186108+369.457491	test-rmse:1598.853858+1896.463822
#
# 64/64 fit!

# %%
# unmount gdrive
drive.flush_and_unmount()
